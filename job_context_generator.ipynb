# %% [markdown]
# # Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import chromadb
from typing import List, Dict

from sentence_transformers import SentenceTransformer
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
from urllib.parse import urlparse, urljoin

def normalize_url(base_url, url):
    """Normalize a URL to its canonical form."""
    normalized_url = urljoin(base_url, url)  # Resolve relative URLs
    parsed_url = urlparse(normalized_url)
    # Remove fragment (e.g., #section1) and normalize path
    normalized_url = parsed_url._replace(fragment='').geturl()
    return normalized_url.rstrip('/').lower()  # Remove trailing slash and make lowercase

def is_valid_url(base_url, url):
    """Check if URL is valid, normalized, and within the same domain."""
    try:
        # Normalize the URL
        url = normalize_url(base_url, url)

        # Parse base and target URLs
        parsed_base = urlparse(base_url)
        parsed_url = urlparse(url)

        # Check for valid scheme and domain match
        is_same_domain = parsed_base.netloc == parsed_url.netloc
        is_valid_scheme = parsed_url.scheme in ('http', 'https')

        # Exclude non-HTML file types
        excluded_extensions = ['.pdf', '.jpg', '.png', '.gif', '.zip', '.exe', '.docx', '.mp4']
        has_valid_extension = not any(parsed_url.path.lower().endswith(ext) for ext in excluded_extensions)

        return is_valid_scheme and is_same_domain and has_valid_extension
    except Exception:
        return False

from hashlib import md5

def get_page_hash(content):
    """
    Generate a unique hash for the page content.
    
    Args:
        content (str): The text content of the page.

    Returns:
        str: MD5 hash of the content.
    """
    return md5(content.encode('utf-8')).hexdigest()

def crawl_website(base_url, max_pages=100):
    """Crawl the entire website and collect text content"""
    visited_urls = set()
    company_content = []

    def recursive_crawl(url):
        if (url in visited_urls or 
            len(visited_urls) >= max_pages):
            return
    
        try:
            # Normalize URL
            url = normalize_url(base_url, url)
    
            # Avoid revisiting normalized URLs
            if url in visited_urls:
                return
    
            visited_urls.add(url)
    
            # Fetch page content
            response = requests.get(url, timeout=10)
            soup = BeautifulSoup(response.text, 'html.parser')
    
            # Extract text content
            page_text = soup.get_text(separator=' ', strip=True)
            content_hash = get_page_hash(page_text)
            if content_hash not in visited_urls:
                visited_urls.add(content_hash)
                company_content.append({
                    'url': url,
                    'content': page_text
                })
    
            # Find and crawl subpages
            for link in soup.find_all('a', href=True):
                full_url = urljoin(base_url, link['href'])
                full_url = normalize_url(base_url, full_url)
                if is_valid_url(base_url, full_url):
                    recursive_crawl(full_url)
    
        except Exception as e:
            print(f"Error crawling {url}: {e}")

    # Start crawling from base URL
    recursive_crawl(base_url)
    return company_content

# %%
def clean_text(text: str) -> str:
    """
    Clean text by removing special characters and formatting artifacts
    """
    import re

    cleaned_text = re.sub(r'[^\x00-\x7F]+', ' ', text)

    # Step 2: Replace multiple spaces with a single space
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)

    # Step 3: Optionally trim leading/trailing spaces
    cleaned_text = cleaned_text.strip()

    # Remove non-breaking spaces
    cleaned_text = cleaned_text.replace('\xa0', ' ')
    
    # Remove copyright symbols
    cleaned_text = cleaned_text.replace('Â©', '©')
    
    # Remove multiple spaces
    cleaned_text = ' '.join(cleaned_text.split())
    
    # Remove any remaining control characters
    cleaned_text = ''.join(char for char in cleaned_text if ord(char) >= 32 or char == '\n')
    
    return cleaned_text

# %% [markdown]
# # Create Embeddings and store in Vector Database

# %%
def _index_documents(documents:List[str], client, collection):
    """
    Convert documents to embeddings and store in vector database
    """
    embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
    
    for i, doc in enumerate(documents):
        # Generate embedding
        embedding = embedding_model.encode(doc).tolist()
        
        # Store in vector database
        collection.add(
            embeddings=embedding,
            documents=[doc],
            ids=[f"doc_{i}"]
        )

# %% [markdown]
# # Ingest Resume

# %%
import pdfplumber

# Open the PDF file
def read_resume(path):
    with pdfplumber.open(path) as pdf:
        # Extract text from all pages
        full_text = ""
        for page in pdf.pages:
            # Extract text with improved precision
            page_text = page.extract_text()
            full_text += page_text + "\n"
    
    return full_text

# %%
import re

def extract_bullet_points(resume_text):
    # Split the text into lines
    lines = resume_text.split('\n')
    
    # List to store complete bullet points
    bullet_points = []
    
    # Temporary storage for multi-line bullets
    current_bullet = None
    
    for line in lines:
        # Check if line starts with a bullet
        if re.match(r'^[\-\*•●]\s|\d+\.\s', line.strip()):
            # If we were building a previous multi-line bullet, add it first
            if current_bullet:
                bullet_points.append(' '.join(current_bullet))
            
            # Start a new bullet point
            current_bullet = [line.strip()]
        
        # Check for continuation of a bullet point (indented or without a new bullet)
        elif current_bullet is not None and (line.strip() and not re.match(r'^[\-\*•●]\s|\d+\.\s', line.strip())):
            # Append to current bullet point
            current_bullet.append(line.strip())
        
        # If line is empty, reset current bullet
        elif line.strip() == '':
            # Add any ongoing bullet point
            if current_bullet:
                bullet_points.append(' '.join(current_bullet))
                current_bullet = None
    
    # Add the last bullet point if exists
    if current_bullet:
        bullet_points.append(' '.join(current_bullet))
    
    return bullet_points

# %%
import chromadb
from sentence_transformers import SentenceTransformer
from openai import OpenAI
from typing import List

class StrictContextGenerator:
    def __init__(self, openai_api_key: str, vector_db_collection):
        """
        Initialize context generator with strict document retrieval
        
        Args:
            openai_api_key (str): OpenAI API key
            vector_db_collection: ChromaDB collection of embedded documents
        """
        self.client_ai = OpenAI(api_key=openai_api_key)
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
        self.collection = vector_db_collection
        
    def retrieve_relevant_context(self, query: str, top_k: int = 3) -> List[str]:
        """
        Retrieve most relevant documents based on both explicit and implicit connections
        
        Args:
            query (str): Query to find relevant context
            top_k (int): Number of top documents to retrieve
        
        Returns:
            List of most relevant document contexts combining explicit and implicit matches
        """
        # Generate two query perspectives
        explicit_query = query  # Original query for exact/direct matches
        implicit_query = f"Skills, methods, or approaches related to: {query}"  # For conceptual connections
        
        # Create embeddings for both queries
        explicit_embedding = self.embedding_model.encode(explicit_query).tolist()
        implicit_embedding = self.embedding_model.encode(implicit_query).tolist()
        
        # Perform semantic search for both perspectives
        explicit_results = self.collection.query(
            query_embeddings=explicit_embedding,
            n_results=top_k
        )
        
        implicit_results = self.collection.query(
            query_embeddings=implicit_embedding,
            n_results=top_k
        )
        
        # Combine and deduplicate results
        all_docs = []
        if explicit_results['documents']:
            all_docs.extend(explicit_results['documents'][0])
        if implicit_results['documents']:
            all_docs.extend(implicit_results['documents'][0])
            
        # Remove duplicates while preserving order
        unique_docs = list(dict.fromkeys(all_docs))
        
        # Return combined results up to requested number
        return unique_docs[:top_k]
        
    def generate_grounded_context(self, 
                                  query: str, 
                                  retrieved_docs: List[str], 
                                  instruction: str) -> str:
        """
        Generate context using only retrieved documents
        
        Args:
            query (str): Original query or context request
            retrieved_docs (List[str]): Relevant retrieved documents
            instruction (str): Specific generation instruction
        
        Returns:
            Context generated strictly from retrieved documents
        """
    
        # If no documents retrieved, return a cautionary message
        if not retrieved_docs:
            return "Insufficient contextual information to generate a detailed response."
        
        # Prepare prompt with strict grounding
        prompt = f"""
        IMPORTANT INSTRUCTIONS:
        - Use ONLY the information from the provided documents
        - Do NOT add any information not present in the documents
        - If information is missing, state that clearly
        
        Context Documents:
        {chr(10).join([f"Document {i+1}: {doc}" for i, doc in enumerate(retrieved_docs)])}
        
        {instruction}
        
        Query: {query}
        
        Response Guidelines:
        1. Directly quote or paraphrase from the documents
        2. Clearly indicate the source of each piece of information
        3. If no direct information is available, state "No specific information found"
        """
        
        try:
            response = self.client_ai.chat.completions.create(
                model="gpt-4",
                messages=[
                    {"role": "system", "content": "You are a precise document analyst. Only use information from the provided documents."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=500  # Limit response length
            )
            
            return response.choices[0].message.content
        except Exception as e:
            print(f"Error generating grounded context: {e}")
            return f"Error generating context: Unable to process documents. {str(e)}"
    
    def generate_job_seeker_context(self, 
                                    resume: str, 
                                    job_description: str, 
                                    company_context: str) -> str:
        """
        Generate job seeker context using both provided company context and retrieved documents
        
        Args:
            resume (str): Candidate's resume
            job_description (str): Job description
            company_context (str): Additional company context
        
        Returns:
            Contextualized narrative for job seeker
        """
        # Retrieve relevant company context
        query = f"Company information relevant to {job_description} and {company_context}"
        retrieved_docs = self.retrieve_relevant_context(query)
        
        # Add the provided company context to retrieved documents
        if company_context:
            retrieved_docs.insert(0, company_context)
        
        # Generate context with strict document grounding
        context_instruction = """
        Analyze how the candidate's resume matches the job description 
        using the provided company documents.
        
        For each skill or experience, identify:
        - Direct references in company documents
        - Potential alignment with company needs
        - Limitations in context (if any)
        """
        
        return self.generate_grounded_context(
            query=job_description,
            retrieved_docs=retrieved_docs,
            instruction=context_instruction
        )
    
    def generate_recruiter_context(self, 
                                   resume_line: str, 
                                   job_description: str) -> str:
        """
        Generate recruiter context using both provided company context and retrieved documents
        
        Args:
            resume_line (str): Specific line from resume
            job_description (str): Job description
            company_context (str): Additional company context
        
        Returns:
            Detailed contextual breakdown
        """
        # Retrieve relevant company context
        query = f"Company information related to {resume_line}"
        #{job_description} and
        retrieved_docs = self.retrieve_relevant_context(query)
        
        # Add the provided company context to retrieved documents
        #if company_context:
        #   retrieved_docs.insert(0, company_context)
        
        # Generate context with strict document grounding
        context_instruction = """
        Analyze this resume achievement in the context of the job and company:
        
        For each aspect of the resume line, identify:
        - Direct supporting evidence from company documents
        - Potential relevance to company needs
        - Any gaps in contextual information
        - Explicitly quote or reference source documents
        """
        
        return self.generate_grounded_context(
            query=resume_line,
            retrieved_docs=retrieved_docs,
            instruction=context_instruction
        )

# %%
client = chromadb.Client()
existing_collections = client.list_collections()

# Check if "company_docs" collection exists
collection_exists = any(collection.name == "company_docs" for collection in existing_collections)

if collection_exists:
    # Collection already exists, so just get the existing collection
    collection = client.get_collection("company_docs")
else:
    # Create the collection
    collection = client.create_collection("company_docs")

# %%
JOB_DESCRIPTION = """Exowatt is a next generation renewable energy company offering commercial and industrial customers a modular full-stack energy solution that can provide dispatchable power and heat for up to 24 hours per day, specifically designed to meet the needs of energy-intensive applications such as data centers. Our mission is clear, to make sustainable renewable energy always available and almost free. Exowatt is based in Miami, Florida and backed by notable investors such as a16z, Atomic, and Sam Altman.

We are looking for a driven, self-starter fullstack engineer to help us build out customer facing interfaces and build out the backend firmware. You will work closely with our small team of Mechanical, Thermal, and Optics engineers and have significant inputs to the product success.

What You'll Do:
In your first six months on the job you’ll have:
- Understood the company’s vision, goals, business model, and the challenges that our customers face.
- Worked closely with our pilot users to solve their problems through elegant technical solutions.
- Defined the medium-term technical strategy with a keen focus on incorporating business needs, user feedback, and the inherent flexibility required in an early stage-startup.
- Led the release of the minimum viable product by working throughout the stack - backend, frontend, and infrastructure, with an emphasis on firmware and front end development.
- Developed a data engineering strategy to synthesize data from disparate sources into an analysis ready state.
- Made key improvements to our underlying infrastructure, and laid out the medium term architecture roadmap.
- Helped recruit additional technical team members to form a world-class, collaborative team.
- Established technical culture by setting best practices and norms.
- Led the release of subsequent versions of the product, with a focus on third-party data integrations, to unblock new business and enable growth.

What You Have:
- 3-5+ yrs of total full time software development experience.
- 1-2+ yrs of experience with firmware development.
- Experience with scripting languages (ex. Python) and automation tools.
- Experience with integration and tooling software.
- Familiarity with cloud-based computing platforms (ex. AWS, Google Cloud).
- Experience with multiple database management systems.
- Strong problem-solving, debugging, and analytical skills with great attention to detail.
- 0->1 startup experience, ideally with a Pre-seed / Seed / Series A company
$140,000 - $180,000 a year
We are focused on building a diverse and inclusive workforce. If you’re excited about this role, but do not meet 100% of the qualifications listed above, we encourage you to apply.
-----
Exowatt is an Equal Opportunity Employer and considers applicants for employment without regard to race, color, religion, sex, orientation, national origin, age, disability, genetics or any other basis forbidden under federal, state, or local law. Exowatt considers all qualified applicants in accordance with the San Francisco Fair Chance Ordinance.

Please review our CCPA policies here.

"""

# %%
import os
def main():
    # Example usage
    # Replace with actual values
    #OPENAI_API_KEY = os.getenv('OPENAI_API_KEY', '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')
    #COMPANY_URL = 'https://example.com'
    #RESUME_PATH = 'path/to/resume.pdf'
    #JOB_DESCRIPTION = 'Detailed job description here'

    # Crawl website
    url = "https://www.exowatt.com/"

    content = crawl_website(url)
    content = [clean_text(c['content']) for c in content]

    #all_content = [doc['content'] for doc in content]

    # Index documents
    
    _index_documents(content, client, collection)

    # Process resume
    path = "/Users/Tapan/Documents/Dangarwala_Tapan_Resume_cs.pdf"
    all_resume_text = read_resume(path)
    bullet_points = extract_bullet_points(all_resume_text)

    # Generate contexts
    context_generator = StrictContextGenerator(
        openai_api_key='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',
        vector_db_collection=collection)
    
    # Job seeker context
    #job_seeker_context = context_generator.generate_job_seeker_context(
    #    bullet_points[0][2:], 
    #    JOB_DESCRIPTION, 
    #    all_content
    #)
    #print("Job Seeker Context:", job_seeker_context)

    # Recruiter context (using first bullet point)
    if bullet_points:
        for b in bullet_points:
            recruiter_context = context_generator.generate_recruiter_context(
                b,
                JOB_DESCRIPTION
            )
            print(b)
            print("Recruiter Context:", recruiter_context)

# %%
main()
# Out:
# docs found
# ["Terms - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now Privacy Policy and Terms of Use Privacy Policy Privacy Policy Privacy Policy of Exowatt, Inc. Last updated: 4/20/2024 . Introduction Welcome to Exowatt, Inc. We respect your privacy and are committed to protecting your personal data. This Privacy Policy explains how we collect, use, and share information from or about you when you visit our website. 2. Information We CollectPersonal Data: When you fill out our contact form, we collect the personal information you provide, such as your name, email address, company name, and any other information you choose to include. Cookies and Usage Data: We collect certain data through cookies and similar technologies to enhance your user experience. This may include your IP address, browser type, device type, and activity on our site. These may be used by our online data partners or vendors to associate these activities with other personal information they or others have about you, including by association with your email or home address. We (or service providers on our behalf) may then send communications and marketing to these email or home addresses. You may opt out of receiving this advertising by visiting https://app.retention.com/optout . 3. Use of Your Information Your information is used to:Communicate with you, including responding to your inquiries or requests.Improve our website functionality and user experience.Ensure legal compliance with applicable laws and regulations. 4. Legal Basis for Processing (GDPR) For residents of the European Union, we process your personal data under the following legal bases:Your consent, which you can withdraw at any time.The necessity to fulfill a contract with you.Compliance with our legal obligations.Our legitimate interests, such as improving our services and maintaining site security. 5. Your Rights Under GDPR and CCPA Under the GDPR and CCPA, you have the right to:Access the personal information we hold about you.Request the correction of incorrect or incomplete information.Request deletion of your personal data.Object to processing of your data.Request restriction of processing your data.Request transfer of your data to another service.Withdraw your consent at any time where we rely on consent to process your personal data.California residents also have the right to:Know what personal data is being collected about them.Know whether their personal data is sold or disclosed and to whom.Say no to the sale of personal data.Access their personal data.Request deletion of their personal information 6. Data Security We implement appropriate security measures to protect your personal data from unauthorized access, alteration, or destruction. 7. International Data Transfers Your information may be transferred to and maintained on computers located outside of your state, province, country, or other governmental jurisdiction where the data protection laws may differ from those of your jurisdiction. 8. Cookies Policy We use cookies to improve and personalize your experience on our site. You may manage your cookie preferences through your browser settings. 9. Changes to This Privacy Policy We may update our Privacy Policy from time to time. We will notify you of any changes by posting the new policy on our website. 10. Contact Us If you have any questions about this Privacy Policy or our treatment of your personal data, please contact us at: Email: info@exowatt.com Address: 525 NW 29th St, Miami, FL 33127 Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit ...
# • Implemented real time association algorithms, in C++, improving accuracy in ambiguous lane type/color scenarios by 15%.
# Recruiter Context: Achievement: "Implemented real time association algorithms, in C++, improving accuracy in ambiguous lane type/color scenarios by 15%."
#
# 1. Direct Supporting Evidence from Company Documents:
# No specific information was found in the provided documents related to the direct context of this achievement.
#
# 2. Potential Relevance to Company Needs:
# As a renewable energy company, Exowatt could potentially use real time association algorithms to improve the efficiency, accuracy, and functionality of their systems, processes, or products. However, there's no explicit information provided in the documents indicating the company's need for such improvement in their systems, processes, or products.
#
# 3. Any Gaps in Contextual Information:
# The documents do not provide any context related to the utilization or implementation of algorithms, C++, lane type/color scenarios, or accuracy improvements within Exowatt's operations.
#
# 4. Explicitly Quote or Reference Source Documents:
# Since no explicit information was provided in the documents relating to the achievement statement, there are no direct quotes or references that can be made in this context. The primary information about Exowatt from the documents highlights it as a next-generation renewable energy company offering a modular full-stack energy solution for commercial and industrial customers (Document 3).
# docs found
# ["Terms - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now Privacy Policy and Terms of Use Privacy Policy Privacy Policy Privacy Policy of Exowatt, Inc. Last updated: 4/20/2024 . Introduction Welcome to Exowatt, Inc. We respect your privacy and are committed to protecting your personal data. This Privacy Policy explains how we collect, use, and share information from or about you when you visit our website. 2. Information We CollectPersonal Data: When you fill out our contact form, we collect the personal information you provide, such as your name, email address, company name, and any other information you choose to include. Cookies and Usage Data: We collect certain data through cookies and similar technologies to enhance your user experience. This may include your IP address, browser type, device type, and activity on our site. These may be used by our online data partners or vendors to associate these activities with other personal information they or others have about you, including by association with your email or home address. We (or service providers on our behalf) may then send communications and marketing to these email or home addresses. You may opt out of receiving this advertising by visiting https://app.retention.com/optout . 3. Use of Your Information Your information is used to:Communicate with you, including responding to your inquiries or requests.Improve our website functionality and user experience.Ensure legal compliance with applicable laws and regulations. 4. Legal Basis for Processing (GDPR) For residents of the European Union, we process your personal data under the following legal bases:Your consent, which you can withdraw at any time.The necessity to fulfill a contract with you.Compliance with our legal obligations.Our legitimate interests, such as improving our services and maintaining site security. 5. Your Rights Under GDPR and CCPA Under the GDPR and CCPA, you have the right to:Access the personal information we hold about you.Request the correction of incorrect or incomplete information.Request deletion of your personal data.Object to processing of your data.Request restriction of processing your data.Request transfer of your data to another service.Withdraw your consent at any time where we rely on consent to process your personal data.California residents also have the right to:Know what personal data is being collected about them.Know whether their personal data is sold or disclosed and to whom.Say no to the sale of personal data.Access their personal data.Request deletion of their personal information 6. Data Security We implement appropriate security measures to protect your personal data from unauthorized access, alteration, or destruction. 7. International Data Transfers Your information may be transferred to and maintained on computers located outside of your state, province, country, or other governmental jurisdiction where the data protection laws may differ from those of your jurisdiction. 8. Cookies Policy We use cookies to improve and personalize your experience on our site. You may manage your cookie preferences through your browser settings. 9. Changes to This Privacy Policy We may update our Privacy Policy from time to time. We will notify you of any changes by posting the new policy on our website. 10. Contact Us If you have any questions about this Privacy Policy or our treatment of your personal data, please contact us at: Email: info@exowatt.com Address: 525 NW 29th St, Miami, FL 33127 Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit ...
# • Designed and built API in Python for sensor fusion algorithm (Kalman Filter) analysis that incorporated 60+ custom metrics to evaluate and visualize behavior in all test and customer datasets.
# Recruiter Context: Direct Supporting Evidence from Company Documents: No specific information found in the provided documents regarding the specific job achievement of designing and building an API in Python for sensor fusion algorithm analysis incorporating 60+ custom metrics for evaluating and visualizing behavior in test and customer datasets.
#
# Potential Relevance to Company Needs: Exowatt is a next-generation renewable energy company that offers energy solutions for commercial and industrial customers (Document 2). Having a team member with experience in building and designing APIs, especially for evaluating and visualizing large amounts of data could potentially be beneficial for the company. This is likely to aid in system analysis, decision-making, and improving the functionalities of their products/services.
#
# Gaps in Contextual Information: The documents do not provide specific details about the technical skills required for a role in the company, the specific duties of the role, or whether there is a direct need for Python API design and implementation skills or experience with sensor fusion algorithm analysis.
#
# Relevant Quotes or References:
# - "Exowatt is a next-generation renewable energy company offering a modular full-stack energy solution for commercial and industrial customers" (Document 2).
# - There's no information in the document regarding the need for technical skills like designing and building APIs or using Python for algorithm analysis.
# docs found
# ["Contact - Exowatt Home About Contact Us Reserve Now Get in touch Need to contact us? No problem. Please use our contact form below. Full name Email address Company name Message Thank you! We ll get back to you soon We've received your message and someone at Exowatt will get back to you as soon as possible. Oops! Something went wrong. Follow us on Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "Exowatt Home About Contact Us Reserve Now Checkout Please review your checkout details below. If everything is correct, place your order and you will receive more information via email. Customer Info * Required Email * Shipping Address * Required Full Name * Street Address * City * State/Province Zip/Postal Code * Country * United States Shipping Method $ 0.00 USD No shipping methods are available for the address given. Payment Info * Required Card Number * Expiration Date * Security Code * Billing address same as shipping Billing Address * Required Full Name * Street Address * City * State/Province Zip/Postal Code * Country * Afghanistan Aland Islands Albania Algeria American Samoa Andorra Angola Anguilla Antigua and Barbuda Argentina Armenia Aruba Australia Austria Azerbaijan Bahamas Bahrain Bangladesh Barbados Belarus Belgium Belize Benin Bermuda Bhutan Bolivia Bonaire, Saint Eustatius and Saba Bosnia and Herzegovina Botswana Brazil British Indian Ocean Territory British Virgin Islands Brunei Bulgaria Burkina Faso Burundi Cabo Verde Cambodia Cameroon Canada Cayman Islands Central African Republic Chad Chile China Christmas Island Cocos Islands Colombia Comoros Cook Islands Costa Rica Croatia Cuba Curacao Cyprus Czechia Democratic Republic of the Congo Denmark Djibouti Dominica Dominican Republic Ecuador Egypt El Salvador Equatorial Guinea Eritrea Estonia Eswatini Ethiopia Falkland Islands Faroe Islands Fiji Finland France French Guiana French Polynesia French Southern Territories Gabon Gambia Georgia Germany Ghana Gibraltar Greece Greenland Grenada Guadeloupe Guam Guatemala Guernsey Guinea Guinea-Bissau Guyana Haiti Honduras Hong Kong Hungary Iceland India Indonesia Iran Iraq Ireland Isle of Man Israel Italy Ivory Coast Jamaica Japan Jersey Jordan Kazakhstan Kenya Kiribati Kosovo Kuwait Kyrgyzstan Laos Latvia Lebanon Lesotho Liberia Libya Liechtenstein Lithuania Luxembourg Macao Madagascar Malawi Malaysia Maldives Mali Malta Marshall Islands Martinique Mauritania Mauritius Mayotte Mexico Micronesia Moldova Monaco Mongolia Montenegro Montserrat Morocco Mozambique Myanmar Namibia Nauru Nepal Netherlands New Caledonia New Zealand Nicaragua Niger Nigeria Niue Norfolk Island North Korea North Macedonia Northern Mariana Islands Norway Oman Pakistan Palau Palestinian Territory Panama Papua New Guinea Paraguay Peru Philippines Pitcairn Poland Portugal Puerto Rico Qatar Republic of the Congo Reunion Romania Russia Rwanda Saint Barthelemy Saint Helena Saint Kitts and Nevis Saint Lucia Saint Martin Saint Pierre and Miquelon Saint Vincent and the Grenadines Samoa San Marino Sao Tome and Principe Saudi Arabia Senegal Serbia Seychelles Sierra Leone Singapore Sint Maarten Slovakia Slovenia Solomon Islands Somalia South Africa South Georgia and the South Sandwich Islands South Korea South Sudan Spain Sri Lanka Sudan Suriname Svalbard and Jan Mayen Sweden Switzerland Syria Taiwan Tajikistan Tanzania Thailand Timor Leste Togo Tokelau Tonga Trinidad and Tobago Tunisia Turkey Turkmenistan Turks and Caicos Islands Tuvalu U.S. Virgin Islands Uganda Ukraine United Arab Emirates United Kingdom United States United States Minor Outlying Islands Uruguay Uzbekistan Vanuatu Vatican Venezuela Vietnam Wallis and Futuna Western Sahara Yemen Zambia Zimbabwe Items in Order Quantity: 1 : $ 0.00 USD Order Summary Subtotal $ 0.00 USD Total Discount Code Apply Place Order Pay with browser. The ...
# • Developed training process for CNN based ground truthing system, using PyTorch and OpenCV with fisheye images, to automate assessment of localization software accuracy in large scale testing (1,000+ vehicles) efforts.
# Recruiter Context: The documents provided do not contain any information or context related to the resume achievement of a candidate stating they developed a training process for a CNN-based ground truthing system with large scale vehicle testing. Therefore, there is no supporting evidence, potential relevance to company need, or any gaps in information that can be identified from the documents concerning this query. The direct quote from these documents is, "No specific information found."
# docs found
# ["FAQs - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now FAQs Commonly asked questions about Exowatt Our Model Our Hardware Our Solution Timeline Our Model What do you mean by almost free? Our first goal was to achieve baseload power at $0.01/kWh, undercutting the low-cost dominance of fossil fuels. To achieve this, we developed a revolutionary technology solution that could compete on price and deliver reliable, sustainable energy. Why does it matter to get the price so low? Our solution offers a 5x cost reduction over fossil fuels, enabling significant savings for energy-intensive industries. This translates to reduced CO2 emissions and increased accessibility for innovative applications. By lowering costs for operators and hyperscalers, we empower a wider population to benefit from AI and other cutting-edge technologies. Benefits: 5x cost reduction compared to fossil fuels Significant savings for energy-intensive industries Reduced CO2 emissions Increased accessibility and wider adoption of innovative applications What does Exowatt do? We provide modular full-stack renewable energy solutions for commercial and industrial use. Our Hardware What is the Exowatt P3? As the name suggests, the P3 is a three in one modular product that harnesses solar energy through specialized lenses and stores it as heat in a long-duration, sensible heat battery. Whats that mean? We are essentially taking energy directly from the sun and storing it in solid blocks made of a special material. Unlike conventional batteries, our design uses a specially developed silicon composite material to store energy without chemical reactions, phase changes, or electrical currents. It s a very simple battery that allows us not only to bring the cost of storage down, but it s incredibly long-lasting without any degradation or maintenance requirements. Or modular full-stack energy solution for commercial and industrial applications has seven benefits: 1. 7.5 KWe peak load power 2. More than 1,000 C high quality heat 3. 12+ hours of storage capacity without degradation and losses because the heat engine is built in 4. Less than four cents levelized cost of energy (LCOE) 5. Made in USA 6. 80% recycled materials 7. Can linearly scale the number of modules for a project compared to large systems that need a lot of lead time. Our Solution Why do we need Exowatt? Don t we already have renewables + storage, and nuclear? Today s renewable energy solutions have five problems: 1. They re not dispatchable; energy is not available as needed and being produced when not needed (aka, the Duck Curve ) 2. No built-in storage; adding electrochemical batteries increases the cost of renewable by over 100% 3. No output variety; heat is 66% of industrial energy use, but solar PV, wind and hydro only produce electricity 4. Not modular: baseload power plants can take up to 10 years and $1B of CapEx to become operational 5. Made in China: China makes 77% of the world s batteries and 80% of the solar panel supply chain . While the cost of generating renewable energy has fallen significantly, the challenge remains that wind and solar are intermittent. We then pair them with batteries, but the prevailing battery technology is electrochemical li-ion degrades and is not a cost-competitive solution. The grid needs something that can really load shift, into the night hours and the evening hours, which we can t do with electrochemical. There is no solution that can truly do that. We re hoping that nuclear and geothermal come online, but ultimately every grid is a mix of diffe ...
# • Reduced module compute by 58% using RTOS (QNX) development tools and Python scripts to log function execution times. Thermal Controls Development Engineer Feb 2022 – Nov 2023
# Recruiter Context: Resume Line: • Reduced module compute by 58% using RTOS (QNX) development tools and Python scripts to log function execution times. Thermal Controls Development Engineer Feb 2022 – Nov 2023
#
# 1. Direct supporting evidence from company documents
#
# No specific information was found in the documents provided about the use of RTOS (QNX) development tools or the need for reduced module compute in Exowatt's operations. There was also no mention of the role or responsibilities of a Thermal Controls Development Engineer in the provided documents.
#
# 2. Potential relevance to company needs
#
# Exowatt appears to specialize in creating energy solutions using renewable resources and new technology (Document 1). The company's hardware, named the Exowatt P3, involves energy storage and modular design (Document 1). Their software provides owners and operators an overview of all assets, with insights down to the module level (Document 2). Therefore, the reduction of module compute may potentially enhance the efficiency of Exowatt's energy solutions.
#
# The Thermal Controls Development Engineer's skills could potentially be relevant to optimizing Exowatt's P3 hardware solution. This individual's experience in Python scripting may contribute to the software side of Exowatt's full-stack solution, particularly in optimizing the operations of the modules.
#
# 3. Any gaps in contextual information
#
# There's a lack of clarity regarding the specific nature of the work carried out by the Thermal Controls Development Engineer and the connection to Exowatt's business, as the company documents provided do not specifically mention this role or the precise technology (RTOS (QNX) development tools) used by this individual.
#
# 4. Explicitly quote or reference source documents
#
# No explicit quotes are identifiable for this profile as the documents do not provide specific information about the utilization of RTOS, Python scripting, module compute reduction, or the function of a Thermal Controls Development Engineer within Exowatt.
# docs found
# ["Home - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now A Bold New Future in Energy Starts Here. A Modular Full-Stack Solution to Modernize Renewable Energy Infrastructure and Transform Sustainable Power. Reserve Now Proudly supported by The Exowatt Solution Combining the Best of Several Technologies Linearly scalable design Our product's capacity and costs grow hand-in-hand. Industrial heat, electricity, and more. Meets 90% of industrial needs and versatile inputs. Made in USA Raw materials sourced and product manufactured domestically. Low cost built-in storage Capable of providing baseload electricity using stored heat in thermal batteries. Flatten the duck curve Store excess energy and dispatch during peak times for consistent availability. Vision Powering World 3.0 Our vision is to Power World 3.0 using affordable, sustainable, renewable energy. Learn More P3 Hardware Exceptional Design and Quality Our hardware fits in a 40-foot shipping container, allowing for rapid deployment and lasting for 30 years. The modular system makes us a great partner for businesses to scale up. Per Unit 25 kWhe Hardware Lifespan 30 + P3 Tech Maximize Efficiency, Minimize Downtime. Our software provides owners and operators an overview of all assets, with insights down to the module level. Monitor performance, identify issues, and optimize operations for maximum efficiency and output. Applications Commercial and Industrial Applications 01 Power Data Centers Overcome soaring energy costs and carbon footprints with our scalable, reliable, and cost-effective energy solution. 02 Get Online Faster Our modular system is capable of being deployed fully behind the meter as baseload power 03 Optimize Energy Consumption Maximize efficiency and reduce costs across many commercial & industrial applications. Press What's being said about Exowatt Sam Altman Invests in Energy Startup Focused on AI Data Center Investment by OpenAI CEO highlights artificial intelligence s electricity appetite. Wall Street Journal Why Sam Altman is Betting on Solar to Power AI The renewable energy company scored $20 Million from the OpenAI CEO and VC firms Andreessen Horowitz and Atomic to satisfy AI's rapidly growing energy needs. INC Altman-Backed Startup Bets on Heat and the Sun to Tackle AI's Massive Carbon Footprint Exowatt has developed an energy generation and storage system that can provide a novel way to power data centers. BLOOMBERG Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "FAQs - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now FAQs Commonly asked questions about Exowatt Our Model Our Hardware Our Solution Timeline Our Model What do you mean by almost free? Our first goal was to achieve baseload power at $0.01/kWh, undercutting the low-cost dominance of fossil fuels. To achieve this, we developed a revolutionary technology solution that could compete on price and deliver reliable, sustainable energy. Why does it matter to get the price so low? Our  ...
# • Co-invented design for optimized electronic expansion valve improving energy balance in heat pump systems (patent filed).
# Recruiter Context: Direct Supporting Evidence from Company Documents:
#
# No specific information was found in the provided documents that directly supports the claim of co-inventing a design for optimized electronic expansion valve to improve energy balance in heat pump systems.
#
# Potential Relevance to Company Needs:
#
# Exowatt is a company focused on providing sustainable, renewable energy solutions that are efficient, reliable and affordable (Document 1). The company’s product, the Exowatt P3, uses a revolutionary technology solution that combines heat and energy storage (Document 2). Therefore, the applicant's experience with optimizing energy balance could be relevant to the company's needs.
#
# Gaps in Contextual Information:
#
# Details on Exowatt's specific use of heat pump systems or relevant technology are missing from the provided documents. Thus, the exact relevancy of the job candidate's co-inventive contribution to an optimized electronic expansion valve improving energy balance in heat pump systems is unclear because the documents do not provide information about Exowatt's current or future use of such technology.
#
# Information References:
#
# The information used to answer this prompt comes from documents 1 and 2. The lack of direct supporting evidence and gaps in contextual information come from the absence of relevant details in all the provided documents.
# docs found
# ["FAQs - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now FAQs Commonly asked questions about Exowatt Our Model Our Hardware Our Solution Timeline Our Model What do you mean by almost free? Our first goal was to achieve baseload power at $0.01/kWh, undercutting the low-cost dominance of fossil fuels. To achieve this, we developed a revolutionary technology solution that could compete on price and deliver reliable, sustainable energy. Why does it matter to get the price so low? Our solution offers a 5x cost reduction over fossil fuels, enabling significant savings for energy-intensive industries. This translates to reduced CO2 emissions and increased accessibility for innovative applications. By lowering costs for operators and hyperscalers, we empower a wider population to benefit from AI and other cutting-edge technologies. Benefits: 5x cost reduction compared to fossil fuels Significant savings for energy-intensive industries Reduced CO2 emissions Increased accessibility and wider adoption of innovative applications What does Exowatt do? We provide modular full-stack renewable energy solutions for commercial and industrial use. Our Hardware What is the Exowatt P3? As the name suggests, the P3 is a three in one modular product that harnesses solar energy through specialized lenses and stores it as heat in a long-duration, sensible heat battery. Whats that mean? We are essentially taking energy directly from the sun and storing it in solid blocks made of a special material. Unlike conventional batteries, our design uses a specially developed silicon composite material to store energy without chemical reactions, phase changes, or electrical currents. It s a very simple battery that allows us not only to bring the cost of storage down, but it s incredibly long-lasting without any degradation or maintenance requirements. Or modular full-stack energy solution for commercial and industrial applications has seven benefits: 1. 7.5 KWe peak load power 2. More than 1,000 C high quality heat 3. 12+ hours of storage capacity without degradation and losses because the heat engine is built in 4. Less than four cents levelized cost of energy (LCOE) 5. Made in USA 6. 80% recycled materials 7. Can linearly scale the number of modules for a project compared to large systems that need a lot of lead time. Our Solution Why do we need Exowatt? Don t we already have renewables + storage, and nuclear? Today s renewable energy solutions have five problems: 1. They re not dispatchable; energy is not available as needed and being produced when not needed (aka, the Duck Curve ) 2. No built-in storage; adding electrochemical batteries increases the cost of renewable by over 100% 3. No output variety; heat is 66% of industrial energy use, but solar PV, wind and hydro only produce electricity 4. Not modular: baseload power plants can take up to 10 years and $1B of CapEx to become operational 5. Made in China: China makes 77% of the world s batteries and 80% of the solar panel supply chain . While the cost of generating renewable energy has fallen significantly, the challenge remains that wind and solar are intermittent. We then pair them with batteries, but the prevailing battery technology is electrochemical li-ion degrades and is not a cost-competitive solution. The grid needs something that can really load shift, into the night hours and the evening hours, which we can t do with electrochemical. There is no solution that can truly do that. We re hoping that nuclear and geothermal come online, but ultimately every grid is a mix of diffe ...
# • Conducted proof-of-concept vehicle testing to develop future controls algorithms and assess feasibility of new hardware for 3 thermal system variants.
# Recruiter Context: Resume Line: Conducted proof-of-concept vehicle testing to develop future controls algorithms and assess feasibility of new hardware for 3 thermal system variants.
#
# 1. Direct supporting evidence from company documents:
#
# No specific information in the provided documents directly supports the "proof-of-concept vehicle testing", "develop future controls algorithms", and "new hardware for 3 thermal system variants" outlined in the resume line.
#
# 2. Potential relevance to company needs:
#
# The documents indicate Exowatt's emphasis on developing energy solutions with a focus on novel hardware and technology. Document 1 references the Exowatt's P3 hardware that harnesses solar energy and stores it as heat in a long-duration battery made from a specialized material ("Our Hardware" section). More specifically, they are keen on a solution, which is long-lasting without any degradation or maintenance requirements
# The candidate's experience with testing to assess the feasibility of new hardware for thermal systems may align with such objectives. Furthermore, the development of control algorithms might be beneficial as the company highlighted how it helps operators and hyperscalers with reducing costs and boosting accessibility.
#
# 3. Any gaps in contextual information:
#
# It's unclear from the current documents whether the company is looking to develop vehicular thermal systems or if they're looking for expertise in this specific area. This represents a potential gap relating to the direct applicability of the candidate's experience described in the resume line.
#
# 4. Explicitly quote or reference source documents:
#
# No direct quotes or references from the documents tie into the resume line. The documents do not contain specific information about conducting proof-of-concept vehicle testing, developing control algorithms, or assessing the feasibility of new hardware for thermal systems. The candidate’s resume implies experience with thermal system hardware, whereas the company's documents exclusively mention energy solutions, particularly in the context of storage and cost reduction.
#
# Overall, the documents do not provide direct evidence linking the specifics of the candidate's experience to the company's disclosed needs and activities, although there is potentially relevant overlap in the broader scope of hardware and technology development for energy solutions.
# docs found
# ["FAQs - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now FAQs Commonly asked questions about Exowatt Our Model Our Hardware Our Solution Timeline Our Model What do you mean by almost free? Our first goal was to achieve baseload power at $0.01/kWh, undercutting the low-cost dominance of fossil fuels. To achieve this, we developed a revolutionary technology solution that could compete on price and deliver reliable, sustainable energy. Why does it matter to get the price so low? Our solution offers a 5x cost reduction over fossil fuels, enabling significant savings for energy-intensive industries. This translates to reduced CO2 emissions and increased accessibility for innovative applications. By lowering costs for operators and hyperscalers, we empower a wider population to benefit from AI and other cutting-edge technologies. Benefits: 5x cost reduction compared to fossil fuels Significant savings for energy-intensive industries Reduced CO2 emissions Increased accessibility and wider adoption of innovative applications What does Exowatt do? We provide modular full-stack renewable energy solutions for commercial and industrial use. Our Hardware What is the Exowatt P3? As the name suggests, the P3 is a three in one modular product that harnesses solar energy through specialized lenses and stores it as heat in a long-duration, sensible heat battery. Whats that mean? We are essentially taking energy directly from the sun and storing it in solid blocks made of a special material. Unlike conventional batteries, our design uses a specially developed silicon composite material to store energy without chemical reactions, phase changes, or electrical currents. It s a very simple battery that allows us not only to bring the cost of storage down, but it s incredibly long-lasting without any degradation or maintenance requirements. Or modular full-stack energy solution for commercial and industrial applications has seven benefits: 1. 7.5 KWe peak load power 2. More than 1,000 C high quality heat 3. 12+ hours of storage capacity without degradation and losses because the heat engine is built in 4. Less than four cents levelized cost of energy (LCOE) 5. Made in USA 6. 80% recycled materials 7. Can linearly scale the number of modules for a project compared to large systems that need a lot of lead time. Our Solution Why do we need Exowatt? Don t we already have renewables + storage, and nuclear? Today s renewable energy solutions have five problems: 1. They re not dispatchable; energy is not available as needed and being produced when not needed (aka, the Duck Curve ) 2. No built-in storage; adding electrochemical batteries increases the cost of renewable by over 100% 3. No output variety; heat is 66% of industrial energy use, but solar PV, wind and hydro only produce electricity 4. Not modular: baseload power plants can take up to 10 years and $1B of CapEx to become operational 5. Made in China: China makes 77% of the world s batteries and 80% of the solar panel supply chain . While the cost of generating renewable energy has fallen significantly, the challenge remains that wind and solar are intermittent. We then pair them with batteries, but the prevailing battery technology is electrochemical li-ion degrades and is not a cost-competitive solution. The grid needs something that can really load shift, into the night hours and the evening hours, which we can t do with electrochemical. There is no solution that can truly do that. We re hoping that nuclear and geothermal come online, but ultimately every grid is a mix of diffe ...
# • Led cross functional team to develop new vehicle thermal model in GT-SUITE and Simulink enabling virtual controls testing and $500,000+ in hardware cost savings.
# Recruiter Context: In response to the query: • Led cross functional team to develop new vehicle thermal model in GT-SUITE and Simulink enabling virtual controls testing and $500,000+ in hardware cost savings.
#
# 1. Direct supporting evidence from company documents
# There is no direct evidence in the documents supporting the claim of leading a cross functional team to develop a new vehicle thermal model in GT-SUITE and Simulink enabling virtual controls testing and $500,000+ in hardware cost savings.
#
# 2. Potential relevance to company needs
# Exowatt has developed a revolutionary technology solution aiming for sustainable and low-cost energy generation, which includes harnessing solar energy and storing it in a long-duration, sensible heat battery (Document 1). Therefore, having experience in developing a thermal model may potentially be relevant to the company's focus on heat storage solutions.
#
# 3. Any gaps in contextual information
# The documents do not provide any information on Exowatt's use or requirement of GT-SUITE or Simulink for their operations. Additionally, there is no mention of the company utilizing cross-functional teams in their operations.
#
# 4. Explicitly quote or reference source documents
# No specific information found that directly quotes or references the development of a new vehicle thermal model in GT-SUITE and Simulink enabling virtual controls testing with significant hardware cost savings in the context of Exowatt's operations. All information regarding company operations discussed was derived from the provided documents.
# docs found
# ["Protected Page - Industrial X - Webflow Ecommerce website template Home About Contact Us Reserve Now Password protected Lorem ipsum dolor sit amet consectetur lacus purus tincidunt mauris dolor molestie suscipit id egestas. Password Incorrect password. Please try again. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "About - Exowatt Home About Contact Us Reserve Now About our company Backed by Andreessen Horowitz, Sam Altman, and Atomic, Exowatt is a next-generation renewable energy company offering a modular full-stack energy solution for commercial and industrial customers. Join Us Our MISSION Powering World 3.0 Our mission is to make sustainable renewable energy always available and almost free. TEAM Working to Revolutionize the Energy Sector Founded in 2023 by Hannan Parvizian and Jack Abraham and incubated in Miami. Exowatt is led by Parvizian, an energy industry veteran with experience at Tesla, General Electric, and Siemens. Abraham, CEO of Atomic, brings his expertise in building successful startups to the team. Join Our Team TEAM CULTURE Working at Exowatt Join Exowatt, where innovation and sustainability meet cutting-edge technology. Vision What drives us Our values are foundational to everything we do. They shape who we are and how we work. Kindness We are dedicated to unwavering kindness. People & Planet We are committed to people and our planet. Sustainable Pursuit We maintain a sustainable supply chain and overarching vision. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "Reserve Home About Contact Us Reserve Now Reserve The Exowatt P3 is a full-stack renewable energy module. It generates, stores, and dispatches energy on demand, scaling to meet your peak power and dispatch demand needs. Ready to reserve? Share some basic details, and our team will be in touch. Contact Information Full Name* Email Address* Phone Number Company* Energy Needs Location United States Outside of the United States State Select State... Alabama Alaska Arizona Arkansas California Colorado Connecticut Delaware Florida Georgia Hawaii Idaho illinois Indiana Iowa Kansas Kentucky Lousiana Maine Maryland Massachusetts Michigan Minnesota Mississippi Missouri Montana Nebraska Nevada New Hampshire New Jersey New Mexico New York North Carolina North Dakota Ohio Oklahoma Oregon Pennsylvania Rhode Island South Carolina South Dakota Tennessee Texas Utah Vermont Virginia Washington West Virginia Wisconsin Wyoming Desired Delivery Date Select Date... 2025 Q1 2025 Q2 2025 Q3 2025 Q4 2026 Q1 2026 Q2 2026 Q3 2026 Q4 Dispatch Hours Select Hours... 8 hours 16 hours 24 hours Desired Peak Power in MW Message Thank you! We ll get back to you soon We've received your message and someone at Exowatt will get back to you as soon as possible. Oops! Something went wrong. Follow us on Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024"]
# • Automated the creation of system validation reports via MATLAB script which reduced time overhead by 75%.
# Recruiter Context: 1. Direct supporting evidence from company documents
#     - No specific information found in the documents to directly support the achievement of automating the creation of system validation reports via MATLAB script.
#
# 2. Potential relevance to company needs
#     - While the documents don't mention a need for system validation reports or the use of MATLAB, the job does involve a technology-heavy sector (renewable energy) which might utilize system validation reports. Automation and efficiencies (as evidenced by a 75% reduction in time overhead) may be valuable given the complexity and scale of their operations (Document 2).
#
# 3. Any gaps in contextual information
#     - The documents don't specifically mention a need for automation skills or knowledge of MATLAB. Information about the company's existing processes or use of MATLAB is also missing.
#
# 4. Explicitly quote or reference source documents
#     - The documents provide general information about Exowatt as a company, its mission to supply almost free sustainable renewable energy, and renewable energy module 'Exowatt P3' (Document 2 and Document 3). No specific mention of system validation reports, MATLAB, or automation are made.
# docs found
# ...
#
# Direct evidence: No specific information found. Document 1 doesn't mention specific software skills or communication protocols required.
#
# 2. Potential relevance to company needs:
#
# The range of software and technical skills could be potentially beneficial to a tech-focused company like Exowatt (Document 1 - "Join Exowatt, where innovation and sustainability meet cutting-edge technology.")
#
# 3. Any gaps in contextual information:
#
# Potential gaps: The exact technical requirements or desired software skills for positions at Exowatt are not given in the provided documents.
#
# 4. Explicitly quote or reference source documents: Document 1 suggests a possible relevance of applicant's skills in a tech-driven environment.
#
# ---
#
# Resume Line: "EDUCATION University of Michigan – Dearborn Apr 2022 Master of Science, Electrical Engineering"
#
# 1. Direct supporting evidence from company documents:
#
# Direct evidence: No specific information found about educational requirements in the company documents.
#
# 2. Potential relevance to company needs:
#
# Given that Exowatt is a next-generation renewable energy company (Document 1), a Master's degree in Electrical Engineering could be relevant and beneficial, depending on the role.
#
# 3. Any gaps in contextual information:
#
# Potential gaps: The specific educational requirements or preferences for positions at Exowatt do not feature in the provided documents.
#
# 4. Explicitly quote or reference source documents: No specific
# docs found
# ["Protected Page - Industrial X - Webflow Ecommerce website template Home About Contact Us Reserve Now Password protected Lorem ipsum dolor sit amet consectetur lacus purus tincidunt mauris dolor molestie suscipit id egestas. Password Incorrect password. Please try again. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "About - Exowatt Home About Contact Us Reserve Now About our company Backed by Andreessen Horowitz, Sam Altman, and Atomic, Exowatt is a next-generation renewable energy company offering a modular full-stack energy solution for commercial and industrial customers. Join Us Our MISSION Powering World 3.0 Our mission is to make sustainable renewable energy always available and almost free. TEAM Working to Revolutionize the Energy Sector Founded in 2023 by Hannan Parvizian and Jack Abraham and incubated in Miami. Exowatt is led by Parvizian, an energy industry veteran with experience at Tesla, General Electric, and Siemens. Abraham, CEO of Atomic, brings his expertise in building successful startups to the team. Join Our Team TEAM CULTURE Working at Exowatt Join Exowatt, where innovation and sustainability meet cutting-edge technology. Vision What drives us Our values are foundational to everything we do. They shape who we are and how we work. Kindness We are dedicated to unwavering kindness. People & Planet We are committed to people and our planet. Sustainable Pursuit We maintain a sustainable supply chain and overarching vision. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "404 Not Found - Exowatt Home About Contact Us Reserve Now Oops! Page not found 404 Looks like you've gotten turned around. Go to homepage A Bold New Future in Energy Starts Here. A Bold New Future in Energy Starts Here. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024"]
# • Experience programming robot obstacle avoidance, kinematics, and path planning algorithms in ROS and Matlab. University of Michigan - Ann Arbor May 2019 Bachelor of Science, Mechanical Engineering, Minor in Computer Science
# Recruiter Context: Resume Line: • Experience programming robot obstacle avoidance, kinematics, and path planning algorithms in ROS and Matlab. University of Michigan - Ann Arbor May 2019 Bachelor of Science, Mechanical Engineering, Minor in Computer Science
#
# Direct supporting evidence from company documents:
# There is no specific information found in documents provided that directly references or supports experience in programming robot obstacle avoidance, kinematics, and path planning algorithms in ROS and Matlab.
#
# Potential relevance to company needs:
# The documents indicate that Exowatt is a renewable energy company with a focus on innovative technologies. However, the documents do not provide specific information regarding the company's need or use for robotics, obstacle avoidance, kinematics, and path planning algorithms, or experience with ROS and Matlab.
#
# Any gaps in contextual information:
# There is a significant gap in information as the documents do not mention or imply the need or use of robotics, ROS, Matlab, or related skills in Exowatt's operations or its company needs.
#
# Explicitly quote or reference source documents:
# Neither of the documents explicitly state or refer to any terms or concepts related to robotics, ROS, Matlab, or the specific skills outlined in the resume line.
# docs found
# ["About - Exowatt Home About Contact Us Reserve Now About our company Backed by Andreessen Horowitz, Sam Altman, and Atomic, Exowatt is a next-generation renewable energy company offering a modular full-stack energy solution for commercial and industrial customers. Join Us Our MISSION Powering World 3.0 Our mission is to make sustainable renewable energy always available and almost free. TEAM Working to Revolutionize the Energy Sector Founded in 2023 by Hannan Parvizian and Jack Abraham and incubated in Miami. Exowatt is led by Parvizian, an energy industry veteran with experience at Tesla, General Electric, and Siemens. Abraham, CEO of Atomic, brings his expertise in building successful startups to the team. Join Our Team TEAM CULTURE Working at Exowatt Join Exowatt, where innovation and sustainability meet cutting-edge technology. Vision What drives us Our values are foundational to everything we do. They shape who we are and how we work. Kindness We are dedicated to unwavering kindness. People & Planet We are committed to people and our planet. Sustainable Pursuit We maintain a sustainable supply chain and overarching vision. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "Contact - Exowatt Home About Contact Us Reserve Now Get in touch Need to contact us? No problem. Please use our contact form below. Full name Email address Company name Message Thank you! We ll get back to you soon We've received your message and someone at Exowatt will get back to you as soon as possible. Oops! Something went wrong. Follow us on Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024", "Protected Page - Industrial X - Webflow Ecommerce website template Home About Contact Us Reserve Now Password protected Lorem ipsum dolor sit amet consectetur lacus purus tincidunt mauris dolor molestie suscipit id egestas. Password Incorrect password. Please try again. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024"]
# • Responsible for design and manufacturing of suspension system for Michigan FSAE Electric Racing Team. VOLUNTEERING Microsoft TEALS Teacher – Intro to Computer Science Class Oct 2019 – Feb 2022
# Recruiter Context: Resume Line: Responsible for design and manufacturing of suspension system for Michigan FSAE Electric Racing Team.
#
# - Direct supporting evidence from company documents: No specific information found.
# - Potential relevance to company needs: While it's not stated explicitly in the documents, Exowatt is a company working with advanced technology on renewable energy. The responsibility of designing and manufacturing a suspension system for a race car could potentially demonstrate the ability to work with complex systems, which might be applicable to the technological elements of Exowatt's work.
# - Any gaps in contextual information: The documents do not provide specific information about the requirements or skills relevant to the job, which might directly relate to designing and manufacturing a suspension system.
# - Explicitly quote or reference source documents: Not available.
#
# Resume Line: VOLUNTEERING Microsoft TEALS Teacher – Intro to Computer Science Class Oct 2019 – Feb 2022
#
# - Direct supporting evidence from company documents: No specific information found.
# - Potential relevance to company needs: While it's not stated directly in the documents, the experience of teaching an Intro to Computer Science class could potentially be relevant to Exowatt because of the technology involved in their work as a renewable energy company. Also, their emphasis on values like kindness might be well matched with someone who has volunteered their time to teach others.
# - Any gaps in contextual information: The documents do not provide specific information about the job requirements or skills that would directly relate to teaching a computer science class.
# - Explicitly quote or reference source documents: Not available.
# docs found
# ["Terms - Exowatt Home About Main pages Sales Home V1 Home V2 Home V3 About Services Service single Products Product single Contact V1 Contact V2 Contact V3 Blog V1 Blog V2 Blog V3 Blog post Coming soon More Webflow Template Utility pages Style guide Start here 404 not found Password protected Licenses Changelog Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now Privacy Policy and Terms of Use Privacy Policy Privacy Policy Privacy Policy of Exowatt, Inc. Last updated: 4/20/2024 . Introduction Welcome to Exowatt, Inc. We respect your privacy and are committed to protecting your personal data. This Privacy Policy explains how we collect, use, and share information from or about you when you visit our website. 2. Information We CollectPersonal Data: When you fill out our contact form, we collect the personal information you provide, such as your name, email address, company name, and any other information you choose to include. Cookies and Usage Data: We collect certain data through cookies and similar technologies to enhance your user experience. This may include your IP address, browser type, device type, and activity on our site. These may be used by our online data partners or vendors to associate these activities with other personal information they or others have about you, including by association with your email or home address. We (or service providers on our behalf) may then send communications and marketing to these email or home addresses. You may opt out of receiving this advertising by visiting https://app.retention.com/optout . 3. Use of Your Information Your information is used to:Communicate with you, including responding to your inquiries or requests.Improve our website functionality and user experience.Ensure legal compliance with applicable laws and regulations. 4. Legal Basis for Processing (GDPR) For residents of the European Union, we process your personal data under the following legal bases:Your consent, which you can withdraw at any time.The necessity to fulfill a contract with you.Compliance with our legal obligations.Our legitimate interests, such as improving our services and maintaining site security. 5. Your Rights Under GDPR and CCPA Under the GDPR and CCPA, you have the right to:Access the personal information we hold about you.Request the correction of incorrect or incomplete information.Request deletion of your personal data.Object to processing of your data.Request restriction of processing your data.Request transfer of your data to another service.Withdraw your consent at any time where we rely on consent to process your personal data.California residents also have the right to:Know what personal data is being collected about them.Know whether their personal data is sold or disclosed and to whom.Say no to the sale of personal data.Access their personal data.Request deletion of their personal information 6. Data Security We implement appropriate security measures to protect your personal data from unauthorized access, alteration, or destruction. 7. International Data Transfers Your information may be transferred to and maintained on computers located outside of your state, province, country, or other governmental jurisdiction where the data protection laws may differ from those of your jurisdiction. 8. Cookies Policy We use cookies to improve and personalize your experience on our site. You may manage your cookie preferences through your browser settings. 9. Changes to This Privacy Policy We may update our Privacy Policy from time to time. We will notify you of any changes by posting the new policy on our website. 10. Contact Us If you have any questions about this Privacy Policy or our treatment of your personal data, please contact us at: Email: info@exowatt.com Address: 525 NW 29th St, Miami, FL 33127 Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit ...
# • Developed and taught new python curriculum to 15 high school students throughout the COVID-19 pandemic.
# Recruiter Context: Direct Supporting Evidence from Company Documents: No specific information found. The provided company documents do not contain direct information about the job seeker's accomplishment of developing and teaching a new Python curriculum to high school students.
#
# Potential Relevance to Company Needs: No specific information found. The company's documents do not provide any information suggesting that developing and teaching a Python curriculum is relevant to its operations or needs.
#
# Any Gaps in Contextual Information: The documents do not provide information about the company's operations or their needs in terms of skill set or experience. It is unclear whether skills in Python or teaching experience are relevant or beneficial to the company.
#
# Explicitly Quote or Reference Source Documents:
# - Document 1: "Contact Us Your Cart $ 0.00 USD : Remove Subtotal Pay with browser. Continue to Checkout No items found. Go to shop Product is not available in this quantity. Reserve Now Privacy Policy and Terms of Use Privacy Policy Privacy Policy Privacy Policy of Exowatt, Inc. Last updated: 4/20/2024 . Introduction Welcome to Exowatt, Inc. ..."
# - Document 2: "Password protected Lorem ipsum dolor sit amet consectetur lacus purus tincidunt mauris dolor molestie suscipit id egestas. Password Incorrect password. Please try again. Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024."
# - Document 3: "Contact - Exowatt Home About Contact Us Reserve Now Get in touch Need to contact us? No problem. Please use our contact form below. Full name Email address Company name Message Thank you! We ll get back to you soon We've received your message and someone at Exowatt will get back to you as soon as possible. Follow us on Exowatt Home About FAQs Company Terms Contact Join us Resources Press Kit Exowatt news Don't miss all of our exciting news and updates. Thanks for joining our newsletter. Oops! Something went wrong. Copyright Exowatt | 2024."
